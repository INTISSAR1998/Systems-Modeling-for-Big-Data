# %% [markdown]
# <html> <img style="float:center; margin: 0px 0px 0px 0px;" src="https://docs.google.com/uc? export=download&id=1jIxUCriI-tyCAkUYHz05rk5SY_rTHRV9" width="220" align="left"/> </html>
#
# <figure>
# <center>
# <img src='https://docs.google.com/uc?export=download&id=1BmLEthy7KCNsnVFviFKX77zLmFhc47XZ' align='right'width="220"/>
#
# <figcaption>
#
# </figcaption></center>
# </figure>
# <center> <H1> Analyse et Programmation avec Python </H1> </center>
# <center> <H6> Janvier 2020 </H6> </center>

# %% [markdown]
# Enseignant : Jaafar Chaaouri
#
# Email: Jaafar.chaaouri@fsm.rnu.tn
#
# ---

# %% [markdown]
# # **Chapitre 2 : Numerical Python Stack** <figure>
# <center>
# <img src='https://docs.google.com/uc?export=download&id=1YFzOZPfpTP7kwdlv0kkkKw-DDRzpG6MF' align='center' width=170/>
#
# <figcaption>
#
# </figcaption></center>
# </figure>

# %% [markdown]
#   <dt> Python core : <dt>
#   <dd> objets natifs haut niveau :
#   <dl>
#   <ul>
#   <li>
#   <b> Numériques : </b>   bool, int, float, complex.
#   </li>
#   <li>
#   <b> Itérables :  </b>   str, list, tuple, set, frozenset, dict.
#   </li>
#   </ul>

# %% [markdown]
# ## **Numpy**
# <figure>
# <center>
# <img src='https://docs.google.com/uc?export=download&id=1eadWg0PIG72DraXP5J7s_P9xKWQ0xini' align='center'/>
#
# <figcaption>

# %% [markdown]
#   <dd>
#   <ul>
#   <li> Le module <b> numpy </b> <i> NUMerical PYthon </i> est fondé principalement sur la classe `ndarray` qui permet de faire de la programmation orientée <i> vecteurs </i> . </li>
#
#   <li> `numpy.linalg` : module  de fonctions utilitaires pour l'algèbre linéaire.</li>
#   <li> `numpy.random`: module de fonctionnalités utilitaires pour la génération de vecteurs aléatoires (échantillonnage)  selon différentes lois de probabilités
#   </ul>
#   </dd>

# %% [markdown]
# ## **SciPy** : calcul scientifiques/statistiques avec python
# <figure>
# <center>
# <img src='https://docs.google.com/uc?export=download&id=1IhnDWCJN_L0fwaJj-gZXVGES2VVafGkg' align='right' width='170'/>
#
# <figcaption>

# %% [markdown]
#  "SCIentific PYthon" module offrant des fonctionnalités de calcul scientifique : <dd>
# <li>scipy.integrate : calcul approché d'intégrales, résolution numérique  d'ode. </li>
# <li>scipy.optimize : optimisation, recherche approchée du zéro de système  non linéaire. </li>
# <li> scipy.ndimage : traitement des images numériques, filtrage, convolution, etc. </li> </dd>

# %% [markdown]
# ## **matplotlib**

# %% [markdown]
# module de visualisation des données : traçage des courbes, visualisation d'images 2 ou 3D, etc.
#
# <html> <img style="float:center; margin: 0px 0px 0px 0px;" src="https://docs.google.com/uc? export=download&id=1ZHjN-hDzTvG868s2oU3dyhh-Z--lMGIJ" width="400" align="right"/> </html>
#
# <figure>
# <center>

# %% [markdown]
# ## **Pandas**
#
#
# <html> <img style="float:center; margin: 0px 0px 0px 0px;" src="https://docs.google.com/uc? export=download&id=1DQ_r-qYL7whhMZHeW8VdBornUTw_eFsM" width="400" align="right"/> </html>
#
# <figure>
# <center>

# %% [markdown]
# - les *Series*
# - les *Dataframes*
# - Des exemples de traitement de données publiques

# %% [markdown]
# Un outil pour l'analyse de données
#
#
# - basé sur NumPy
# - Fonctions de chargement et écriture vers les formats de fichiers courants
# - Fonctions de tracé
# - Outils statistiques basiques

# %% [markdown]
# ## **Statsmodels**
#
#
# <html> <img style="float:center; margin: 0px 0px 0px 0px;" src="https://docs.google.com/uc? export=download&id=1XnqWtiU-ka8qI9m7iA3zzeAmJJBLULvP" width="200" align="center"/> </html>
#
#
# <figure>
# <center>

# %% [markdown]
# - Statsmodels est un package Python qui permet aux utilisateurs d'explorer des données, d'estimer des modèles statistiques et d'effectuer des tests statistiques. Une liste complète de statistiques descriptives, de tests, de fonctions de traçage est disponible pour différents types de données. Il complète le module de statistiques de SciPy.
#
# - Statsmodels fait partie de la pile scientifique Python qui est orientée vers l'analyse des données, la science des données et les statistiques. Statsmodels est construit au-dessus des bibliothèques numériques NumPy et SciPy, s'intègre avec Pandas pour le traitement des données. Les fonctions graphiques sont basées sur la bibliothèque Matplotlib. Statsmodels fournit le backend statistique pour d'autres bibliothèques Python.

# %% [markdown]
# ## **Scikit-learn**
#
#
# <html> <img style="float:center; margin: 0px 0px 0px 0px;" src="https://docs.google.com/uc? export=download&id=1DTQfgwJGt0cAbi-hLO8rnPIM_elbFRmC" width="200" align="right"/> </html>
#
#
# <figure>
# <center>

# %% [markdown]
# Scikit-learn est une bibliothèque libre Python destinée à l'apprentissage automatique. Elle est développée par de nombreux contributeurs notamment dans le monde académique par des instituts français d'enseignement supérieur et de recherche comme Inria et Télécom Paris.
